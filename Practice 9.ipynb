# %%
import pandas as pd
movies = pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies[(movies.duration >= 200) & (movies.genre=='Crime')]
# Out:
#     star_rating                        title content_rating  genre  duration  \
# 2           9.1       The Godfather: Part II              R  Crime       200
# 78          8.4  Once Upon a Time in America              R  Crime       229
#
#                                           actors_list
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 78  [u'Robert De Niro', u'James Woods', u'Elizabet...

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies[(movies.duration >=200) & (movies.star_rating >= 9.0) & ((movies.genre=='Crime')|(movies.genre=='Action'))]
# Out:
#    star_rating                   title content_rating  genre  duration  \
# 2          9.1  The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
(movies.genre=='Crime')|(movies.genre=='Action')
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12      True
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19      True
# 20      True
# 21      True
# 22     False
# 23      True
# 24     False
# 25     False
# 26     False
# 27     False
# 28      True
# 29     False
#        ...
# 949    False
# 950     True
# 951    False
# 952    False
# 953    False
# 954     True
# 955    False
# 956    False
# 957    False
# 958    False
# 959    False
# 960    False
# 961    False
# 962    False
# 963     True
# 964    False
# 965    False
# 966    False
# 967     True
# 968    False
# 969     True
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976     True
# 977    False
# 978     True
# Name: genre, Length: 979, dtype: bool

# %%
movies[movies.genre.isin(['Action','Crime'])]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# 21           8.7                                      City of God
# 23           8.7                               The Usual Suspects
# 28           8.6                           Leon: The Professional
# 34           8.6                               American History X
# ...
