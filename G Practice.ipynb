# %%
import pandas as pd

# %%
col= ['rat','tile','con', 'gen ',' dur', 'list ']
im = pd.read_csv('http://bit.ly/imdbratings')
col= ['rat','tile','con', 'gen ',' dur', 'list ']

# %%
im.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
type(im['title'])
# Out:
# pandas.core.series.Series

# %%
im['comb']= im['content_rating'] + "           "+ im['actors_list']

# %%
im.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list  \
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
#
#                                                combo  \
# 0  R [u'Tim Robbins', u'Morgan Freeman', u'Bob Gu...
# 1  R [u'Marlon Brando', u'Al Pacino', u'James Caan']
# ...

# %%
im.describe(include=['object'])
# Out:
#             title content_rating  genre  \
# count         979            976    979
# unique        975             12     16
# top     True Grit              R  Drama
# freq            2            460    278
#
#                                               actors_list  \
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6
#
#                                                     combo  \
# count                                                 976
# unique                                                967
# top     PG-13 [u'Daniel Radcliffe', u'Emma Watson', u'...
# freq                                                    4
#
#                                                      comb
# count                                                 976
# ...

# %%
im.shape
# Out:
# (979, 8)

# %%
im.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list', 'combo', 'comb'],
#       dtype='object')

# %%
col= ['rat', 'tit','con', 'gen', 'time','lisr','co','cooo']
im.columns =col

# %%
im.head()
# Out:
#    rat                       tit    con     gen  time  \
# 0  9.3  The Shawshank Redemption      R   Crime   142
# 1  9.2             The Godfather      R   Crime   175
# 2  9.1    The Godfather: Part II      R   Crime   200
# 3  9.0           The Dark Knight  PG-13  Action   152
# 4  8.9              Pulp Fiction      R   Crime   154
#
#                                                 lisr  \
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
#
#                                                   co  \
# 0  R [u'Tim Robbins', u'Morgan Freeman', u'Bob Gu...
# 1  R [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  R [u'Al Pacino', u'Robert De Niro', u'Robert D...
# 3  PG-13 [u'Christian Bale', u'Heath Ledger', u'A...
# ...

# %%
im.rename(columns={'con':'kon'}, inplace=False)
# Out:
#      rat                                                tit        kon  \
# 0    9.3                           The Shawshank Redemption          R
# 1    9.2                                      The Godfather          R
# 2    9.1                             The Godfather: Part II          R
# 3    9.0                                    The Dark Knight      PG-13
# 4    8.9                                       Pulp Fiction          R
# 5    8.9                                       12 Angry Men  NOT RATED
# 6    8.9                     The Good, the Bad and the Ugly  NOT RATED
# 7    8.9      The Lord of the Rings: The Return of the King      PG-13
# 8    8.9                                   Schindler's List          R
# 9    8.9                                         Fight Club          R
# 10   8.8  The Lord of the Rings: The Fellowship of the Ring      PG-13
# 11   8.8                                          Inception      PG-13
# ...

# %%
im.head()
# Out:
#    rat                       tit    con     gen  time  \
# 0  9.3  The Shawshank Redemption      R   Crime   142
# 1  9.2             The Godfather      R   Crime   175
# 2  9.1    The Godfather: Part II      R   Crime   200
# 3  9.0           The Dark Knight  PG-13  Action   152
# 4  8.9              Pulp Fiction      R   Crime   154
#
#                                                 lisr  \
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
#
#                                                   co  \
# 0  R [u'Tim Robbins', u'Morgan Freeman', u'Bob Gu...
# 1  R [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  R [u'Al Pacino', u'Robert De Niro', u'Robert D...
# 3  PG-13 [u'Christian Bale', u'Heath Ledger', u'A...
# ...
